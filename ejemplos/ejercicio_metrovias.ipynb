# %%
##!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon May 31 

CLASE 5 - Visualizacion de datos con Python
EJERCICIO PROPUESTO
"""
import pandas as pd

# --- Específicas para los gráficos
import matplotlib as mpl
import matplotlib.pyplot as plt
#

# cambiamos la paleta de matplotlib: https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
mpl.style.use('bmh') # bmh es el nombre del estilo que usaremos


## CARGA DE DATOS
metrovias = pd.read_excel("metrovias.xlsx", sheet_name = "Sheet2")

# para ver las primeras observaciones del df
metrovias.head()

# Para ver los tipos de variables del data frame. 
# Necesitamos corroborar que la variables 'mes' esta en formato fecha
metrovias.dtypes
# En este caso la columna "evento" no me sirve asique la descarto
metrovias = metrovias.drop('evento', axis = 'columns')

# %%
# %%
# PRIMERAMENTE REALIZAR EL GRAFICO SOLO
# Definimos los datos que van en los ejes x e y !!
x = 
y = 

# Iniciamos la figura: 12 unidades de eje x, 4 unidades de eje y 
fig, ax = plt.subplots(figsize=(12, 4))  

# DEFINIR EL GRÁFICO -> ax.plot(...)


## SETEAR xlabel, ylabel, title -> recordar ax.set_...

ax.legend(
# Out:
#   File "<ipython-input-2-3e0093c0019a>", line 4
#     x =
#         ^
# SyntaxError: invalid syntax

# %%
#%%
## SE ANIMAN CON EL HISTOGRAMA DE LA VARIABLE 'PASAJEROS'?
fig, ax = plt.subplots(figsize=(8, 4))

## Hist? ax.hist(...)

## Titulo? ax.set_title(...)

## Xlabel? ax.set_xlabel(...)

# %%
# %%
## AGREGAMOS AL GRÁFICO EL MAX, MIN y el PROMEDIO

# 1) Calculamos los valores que queremos incluir en el gráfico
max_pasajeros = 
min_pasajeros = 
avg_pasajeros = 

max_pasajeros, min_pasajeros, avg_pasajeros

## Rehacemos el gráfico original (pegar lo que hicieron arriba)
## Seteamos el gráfico
...

## Agregamos realizamos el grafico de lineas -> ax.plot(...)
...


## Agregamos las líneas horizontales -> ax.axhline(...)
# Máximo - Mismo color y mismo tipo de linea que el minimo (red)
ax.axhline(..., 
           color = , 
           linestyle = , 
           alpha = 0.7,    
           linewidth = 3, 
           label = )
# Mínimo - Mismo color y mismo tipo de linea que el maximo (red)

# Promedio - Distinto color y distinta linea (green)


ax.set_xlabel('Fecha') # Etiqueta eje x
ax.set_ylabel('Cantidad pasajeros') # Etiqueta eje y
ax.set_title('Pasajeros metrovias') # Título
ax.legend() # Inserto la leyenda loc = 'upper_right'

# %%
# %%
## UN EXTRA - AGREGAR UNA LINE VERTICAL EN LA FECHA QUE ALCANZA EL MÁXIMO
# Fecha en la que alcanza el máximo -> filtrar el data frame en el max de pasajeros
fecha_max = 

# Fecha en donde alcanza el máximo
ax.axvline(..., 
           color=, 
           linestyle=, 
           alpha=0.5, 
           linewidth=2, 
           label='Fecha máx')

# %%
# %%
# SUBGRAFICOS
# REALIZAR LOS GRÁFICOS AÑOS 1998, 2008 Y 2014
# HACERLO EN 3 COLUMNAS 
# AGREGAR, SI ES POSIBLE, UNA LINEA VERTICAL CON EL PROMEDIO EN CADA UNO DE LOS AÑOS

metrovias_1998 = 
metrovias_2008 = 
metrovias_2014 = 


fig, ax = plt.subplots(nrows=1, # cantidad filas
                       ncols=3, # cantidad de columnas
                       figsize=(12, 5), # tamano del grafico
                       sharex = True, 
                       sharey = True) # subgráficos comparten la escala en el eje y


ax[0].plot(, , label=)
ax[1].plot(, , label=)
ax[2].plot(, , label=)

ax[0].set_title('Pasajeros Metrovias')
ax[2].set_xlabel('Año')  
ax[1].set_ylabel('Pasajeros')

ax[0].legend()  
ax[1].legend()
ax[2].legend()    

## QUE PASA QUE VEN FEO LOS GRÁFICOS? POR QUE NO QUEDA IGUAL QUE EL DE EVA?
## QUÉ PARÁMETRO SE DEBERÍA CAMBIAR PARA QUE CADA UNO TENGA SU PROPIO EJE X???
